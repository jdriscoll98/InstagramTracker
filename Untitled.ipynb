# %%
from InstagramAPI import InstagramAPI
import numpy as np
import time
username = 'j_driscoll98'
pwd = 'Sax2Drums4Life3'
API = InstagramAPI(username,pwd)
API.login()
time.sleep(2)
# Out:
# Request return 429 error!
# {'message': 'Please wait a few minutes before you try again.', 'status': 'fail'}
# Request return 405 error!
# {'message': '', 'status': 'fail'}
# Request return 404 error!
# Login success!

# %%
API.getProfileData()
API.LastJson.keys()
# Out:
# dict_keys(['user', 'status'])

# %%
print API.LastJson['user'].keys()
my_id = API.LastJson['user']['pk']
# Out:
#   File "<ipython-input-5-1e20a8239b12>", line 1
#     print API.LastJson['user'].keys()
#             ^
# SyntaxError: invalid syntax

# %%
print(API.LastJson['user'].keys())
my_id = API.LastJson['user']['pk']
# Out:
# dict_keys(['pk', 'username', 'full_name', 'is_private', 'profile_pic_url', 'profile_pic_id', 'is_verified', 'has_anonymous_profile_picture', 'biography', 'external_url', 'has_biography_translation', 'reel_auto_archive', 'hd_profile_pic_versions', 'hd_profile_pic_url_info', 'show_conversion_edit_entry', 'latest_reel_media', 'allowed_commenter_type', 'birthday', 'phone_number', 'country_code', 'national_number', 'gender', 'email', 'can_link_entities_in_bio'])

# %%
API.getUsernameInfo(my_id)
n_media = API.LastJson['user']['media_count']

# %%
n_media
# Out:
# 152

# %%
media_ids = []
max_id = ''
for i in range(int(n_media/18+1)): 
    API.getUserFeed(usernameId=my_id, maxid = max_id)
    media_ids += API.LastJson['items'] 
    if API.LastJson['more_available']==False:
        print("no more avaliable")            
        break
    max_id = API.LastJson['next_max_id'] 
    print(i, "   next media id = ", max_id, "  ", len(media_ids))
    time.sleep(3)
# Out:
# 0    next media id =  1651080106952619773_224846256    18
# 1    next media id =  1560302581980086818_224846256    36
# 2    next media id =  1433736441867202523_224846256    54
# 3    next media id =  1298758628849544284_224846256    72
# 4    next media id =  1227644603441849898_224846256    90
# 5    next media id =  1071212682630374637_224846256    108
# 6    next media id =  863232510703936931_224846256    126
# 7    next media id =  515388751964513842_224846256    144
# no more avaliable

# %%
likers = []
m_id = 0
print("wait %.1f minutes" % (n_media*2/60.))
for i in range(len(media_ids)):
    m_id = media_ids[i]['id']
    API.getMediaLikers(m_id)
    likers += [API.LastJson]
    time.sleep(2)
print("done!")
# Out:
# wait 5.1 minutes
# done!

# %%
users = []
for i in likers:
        users += map(lambda x: i['users'][x]['username'],
                     range(len(i['users'])))
users_set = set(users)

print("all users = ", len(users), " uniqum users = ", len(users_set))
# Out:
# all users =  35185  uniqum users =  1522

# %%
l_dict = {}
for user in users_set:
   # l_dict structure - {username:number_of_liked_posts} 
   l_dict[user] = users.count(user)

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter
import operator
all_pairs = sorted(l_dict.items(), key=operator.itemgetter(1))
n_users = 10 # top 10 users
pairs = all_pairs[-n_users:]
y = map(lambda y: pairs[y][1], range(len(pairs)))
x = map(lambda y: pairs[y][0], range(len(pairs)))

# %%
fig = plt.figure()
plt.xkcd()
plt.xticks(range(len(pairs)), x, rotation='vertical')
plt.ylim([80, 160])
plt.bar(range(len(pairs)), y)
plt.xlabel('USERS')
plt.ylabel('number of liked posts')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\jd5\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\units.py in get_converter(self, x)
#     154         try:  # Look up in the cache.
# --> 155             return self[type(x)]
#     156         except KeyError:
#
# KeyError: <class 'map'>
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-17-daf7cb513c8f> in <module>
#       3 plt.xticks(range(len(pairs)), x, rotation='vertical')
#       4 plt.ylim([80, 160])
# ----> 5 plt.bar(range(len(pairs)), y)
#       6 plt.xlabel('USERS')
#       7 plt.ylabel('number of liked posts')
#
# c:\users\jd5\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2438     return gca().bar(
#    2439         x, height, width=width, bottom=bottom, align=align,
# -> 2440         **({"data": data} if data is not None else {}), **kwargs)
#    2441
#    2442
#
# c:\users\jd5\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# c:\users\jd5\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2346
#    2347         if orientation == 'vertical':
# -> 2348             self._process_unit_info(xdata=x, ydata=height, kwargs=kwargs)
#    2349             if log:
#    2350                 self.set_yscale('log', nonposy='clip')
#
# c:\users\jd5\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\axes\_base.py in _process_unit_info(self, xdata, ydata, kwargs)
#    2124
#    2125         kwargs = _process_single_axis(xdata, self.xaxis, 'xunits', kwargs)
# -> 2126         kwargs = _process_single_axis(ydata, self.yaxis, 'yunits', kwargs)
#    2127         return kwargs
#    2128
#
# c:\users\jd5\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\axes\_base.py in _process_single_axis(data, axis, unit_name, kwargs)
#    2106                 # We only need to update if there is nothing set yet.
#    2107                 if not axis.have_units():
# -> 2108                     axis.update_units(data)
#    2109
#    2110             # Check for units in the kwargs, and if present update axis
#
# c:\users\jd5\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\axis.py in update_units(self, data)
#    1485         """
#    1486
# -> 1487         converter = munits.registry.get_converter(data)
#    1488         if converter is None:
#    1489             return False
#
# c:\users\jd5\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\units.py in get_converter(self, x)
#     156         except KeyError:
#     157             try:  # If cache lookup fails, look up based on first element...
# --> 158                 first = cbook.safe_first_element(x)
#     159             except (TypeError, StopIteration):
#     160                 pass
#
# c:\users\jd5\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\cbook\__init__.py in safe_first_element(obj)
#    1660         except TypeError:
#    1661             pass
# -> 1662         raise RuntimeError("matplotlib does not support generators "
#    1663                            "as input")
#    1664     return next(iter(obj))
#
# RuntimeError: matplotlib does not support generators as input

# %%
import matplotlib.pyplot as plt

# %%
from matplotlib.ticker import FormatStrFormatter

# %%
import operator

# %%
all_pairs = sorted(l_dict.items(), key=operator.itemgetter(1))

# %%
all_pairs
# Out:
# [('ashleyserna_', 1),
#  ('jesseblogg', 1),
#  ('john_pate', 1),
#  ('g_luchhi', 1),
#  ('jakegale3', 1),
#  ('yungbeckss', 1),
#  ('foodforthought48', 1),
#  ('jayyymm', 1),
#  ('chris_dunne', 1),
#  ('kasie298', 1),
#  ('li0ra_', 1),
#  ('lexrubin', 1),
#  ('zach_weisberg_drums', 1),
#  ('diego_garciariva5', 1),
#  ('alysebogs', 1),
#  ('crooksnlovers', 1),
#  ('iwritesofreely', 1),
#  ('short__shay', 1),
#  ('allysongraham', 1),
#  ('ufaoii', 1),
#  ('alexx_gibson', 1),
#  ('kaykaythor', 1),
#  ('cheyennee_nikayla', 1),
#  ('kathbriano', 1),
#  ('rachelcporter_', 1),
#  ('emmasandersss', 1),
#  ('paheyyy', 1),
#  ('roximamma', 1),
#  ('cheecho2', 1),
#  ('anai_gressier', 1),
#  ('michellerobin26', 1),
#  ('connorlhota', 1),
#  ('_ashleyy196', 1),
#  ('ericdamenace', 1),
#  ('premedveg', 1),
#  ('megannjulia', 1),
#  ('z_shore', 1),
#  ('sardrake_', 1),
#  ('bergeboy', 1),
#  ('_planetmarsz_', 1),
#  ('parker32111', 1),
#  ('itssasbitch', 1),
#  ('mattgorwitz', 1),
#  ('sophmar1057', 1),
#  ('keveenmohall', 1),
#  ('sophia.quintero', 1),
#  ('lando0n', 1),
#  ('ayejay44', 1),
#  ('carolinezomer', 1),
#  ('gabbyferndawgg', 1),
#  ('flav0rtown', 1),
#  ('catherinevites', 1),
#  ('photogenic_aspirations', 1),
#  ('headymarket', 1),
#  ('s_ocampo', 1),
#  ('danicarosen', 1),
#  ('mkbocus', 1),
#  ('kyoungson_', 1),
#  ('mallorybox', 1),
#  ('evanwetter', 1),
#  ('gregstabs', 1),
#  ('laurenruiz', 1),
#  ('madischuman', 1),
#  ('isabelcantu_', 1),
#  ('rmurphs17', 1),
#  ('_victoriaaa_b', 1),
#  ('j_driscoll98', 1),
#  ('bdwood92', 1),
#  ('connor_helm', 1),
#  ('ardenpmeek', 1),
#  ('ufpilam', 1),
#  ('natalya_wozab', 1),
#  ('amy.garcia98', 1),
#  ('nathalie_barreto_', 1),
#  ('pineapple.under.the.sea', 1),
#  ('mattttgabriel', 1),
#  ('holden_miles28', 1),
#  ('gabbymartini', 1),
#  ('elifuhrm', 1),
#  ('rogonerogue', 1),
#  ('emmalovessharks', 1),
#  ('alyssa_dzikowski', 1),
#  ('adamfirestone1', 1),
#  ('jonswill', 1),
#  ('nasty_mentos', 1),
#  ('david.avaloss', 1),
#  ('addy.aj', 1),
#  ('happystariggy', 1),
#  ('cameronperez9', 1),
#  ('abbeyfoels', 1),
#  ('rami_hatem6', 1),
#  ('blairisrael', 1),
#  ('leeannhutker', 1),
#  ('steven_sma', 1),
#  ('sav_alberty', 1),
#  ('jennyagross', 1),
#  ('connor_mcadorey', 1),
#  ('tonys.kitchen', 1),
#  ('andrew_bilter', 1),
#  ('micaylac_', 1),
#  ('angelinamartinezz', 1),
#  ('blazedmermaid', 1),
#  ('jordanngarcia', 1),
#  ('skonjalwar', 1),
#  ('niickrizzo', 1),
#  ('christinagalvan', 1),
#  ('madisonemanuel', 1),
#  ('hchampagne6', 1),
#  ('phoebewilliamsonn', 1),
#  ('corn_welch', 1),
#  ('matthewglick9696', 1),
#  ('xoxo_ashleymarie_xoxo', 1),
#  ('nolan.gif', 1),
#  ('selenababy97', 1),
#  ('adayinthelifeofplank', 1),
#  ('follownewignikitaaarr', 1),
#  ('minyii_', 1),
#  ('emil_rae_', 1),
#  ('davidpretty', 1),
#  ('lexxiiiiiii', 1),
#  ('marlanaarmstrong', 1),
#  ('jonnyhatt', 1),
#  ('mariellabroyles', 1),
#  ('shoshana.leah', 1),
#  ('xox_natie', 1),
#  ('_blevynsjumper', 1),
#  ('viviadams_', 1),
#  ('danyellebes', 1),
#  ('sydkotin', 1),
#  ('bhayes0704', 1),
#  ('galaxyco', 1),
#  ('ashleyzoro', 1),
#  ('madiya_3', 1),
#  ('a_mows', 1),
#  ('bisamusic', 1),
#  ('jadensrjones', 1),
#  ('bigtittybritty10', 1),
#  ('michellevirgilio', 1),
#  ('ashleystpeter', 1),
#  ('ignacio_de_almagro', 2),
#  ('allensorsher', 2),
#  ('jean.0808', 2),
#  ('kylierandle', 2),
#  ('coreybalko', 2),
#  ('leeann_megan', 2),
#  ('queen.sonya04', 2),
#  ('jscho95', 2),
#  ('camiisequii', 2),
#  ('teddibowxo', 2),
#  ('jaredneale', 2),
#  ('_aden_katz_', 2),
#  ('sophia.giff', 2),
#  ('kassidyschae', 2),
#  ('josemmenendez_', 2),
#  ('jmurillo_21', 2),
#  ('tayreg', 2),
#  ('blakedwards11', 2),
#  ('demp.c', 2),
#  ('aarondepaula', 2),
#  ('isiah_jay', 2),
#  ('beth_gibbon', 2),
#  ('_beccarousseau', 2),
#  ('old_account123456777', 2),
#  ('stefaniebaarman', 2),
#  ('reesechasee', 2),
#  ('j.myers1998', 2),
#  ('argenisjn', 2),
#  ('drisc3', 2),
#  ('inyourfaith', 2),
#  ('gabbygross', 2),
#  ('diegozapata3', 2),
#  ('stanley_thegreatpyrenees', 2),
#  ('pilamquavo', 2),
#  ('drew_lamont', 2),
#  ('cece_hsj', 2),
#  ('paulinejohnson_', 2),
#  ('bethanchell', 2),
#  ('justincho4', 2),
#  ('delbroccom', 2),
#  ('beccaschultzz', 2),
#  ('patek_felipe', 2),
#  ('celineexoxo1_', 2),
#  ('blake_meyer', 2),
#  ('lindsaysavigne', 2),
#  ('alyyssamiranda', 2),
#  ('don_bon1', 2),
#  ('robrodriguez7', 2),
#  ('hannahrome', 2),
#  ('robindentel123', 2),
#  ('truji__14', 2),
#  ('amorstephens', 2),
#  ('craig_barr', 2),
#  ('gianna_dimperio', 2),
#  ('sampinson4', 2),
#  ('ashes.all.over', 2),
#  ('dannyordazz', 2),
#  ('nicole_katerinafit', 2),
#  ('k_maerki', 2),
#  ('nicolebowen.jpg', 2),
#  ('jordancolon13', 2),
#  ('ambs_hunter', 2),
#  ('jpetrohovich', 2),
#  ('bandjich20', 2),
#  ('mel_gonzalez', 2),
#  ('andrea_riccobono', 2),
#  ('itsbayz', 2),
#  ('kyliechilders', 2),
#  ('jacob_couvertier', 2),
#  ('jaredhelman_', 2),
#  ('uftoptier', 2),
#  ('ikindaremember91011', 2),
#  ('taylorcrewss', 2),
#  ('noah_villamar', 2),
#  ('jordan.norris22', 2),
#  ('blaine_preston', 2),
#  ('ashleyzackk', 2),
#  ('blakejanssen', 2),
#  ('biamuni', 2),
#  ('lauren.notloren', 2),
#  ('samarabp_', 2),
#  ('lexgiordano', 2),
#  ('shortie2496', 2),
#  ('laurfrish', 2),
#  ('jennifernev', 2),
#  ('oliverhoffman2', 2),
#  ('cynthia_mo', 2),
#  ('nick_hayman15', 2),
#  ('noahalter2', 2),
#  ('bradreiff', 2),
#  ('allyyyjean', 2),
#  ('ryanbink', 2),
#  ('aubreyy_madison', 2),
#  ('chaseliebs', 2),
#  ('nenarbarazi97', 3),
#  ('evan_lipman', 3),
#  ('isabellekaufman_', 3),
#  ('sabrinamitson', 3),
#  ('__haileyscomet__', 3),
#  ('aava96', 3),
#  ('consuljulius', 3),
#  ('laurenmilgrim', 3),
#  ('mariaalejasosa', 3),
#  ('gabaecruz', 3),
#  ('nick5212', 3),
#  ('savannahnicole7', 3),
#  ('danielleof', 3),
#  ('al_ortizz', 3),
#  ('guanche1223', 3),
#  ('fabigaiil', 3),
#  ('najlabrown', 3),
#  ('rachellist', 3),
#  ('justingoldfeder', 3),
#  ('menutters', 3),
#  ('cassi_rose13', 3),
#  ('kendall_phillipss', 3),
#  ('litttle_reddd', 3),
#  ('__nehasharma', 3),
#  ('jacobcarbone', 3),
#  ('robertobettaglio', 3),
#  ('zachjoffe', 3),
#  ('kiloshthecat', 3),
#  ('godspeed_kj', 3),
#  ('keithmillovan', 3),
#  ('_hopeelizabethm_', 3),
#  ('katiekolb_', 3),
#  ('cook.thyme', 3),
#  ('morbegg', 3),
#  ('isaac_gordon', 3),
#  ('seejensen', 3),
#  ('allisongosser', 3),
#  ('rad_madz', 3),
#  ('_sophievmartinez', 3),
#  ('natacha_cecilia', 3),
#  ('lindylyons', 3),
#  ('whiterice_44', 3),
#  ('diegomila', 3),
#  ('_garymattis', 3),
#  ('spencerkrimsky7214', 3),
#  ('b_mitch3', 3),
#  ('jyakymiw', 3),
#  ('andreacastroo_', 3),
#  ('priyaalexanderrr', 3),
#  ('camilayala11', 3),
#  ('jackthevaletdriver', 3),
#  ('leyla_555_', 3),
#  ('sky_wilson2', 3),
#  ('bbbbrrrreeezy', 3),
#  ('_smdee_', 3),
#  ('zsimon89', 3),
#  ('patrickmolen', 3),
#  ('ariellesydney', 3),
#  ('megfonte', 3),
#  ('andrew__prince', 3),
#  ('sophieschifter', 3),
#  ('navarro_natalie', 3),
#  ('briannarodriguez_', 3),
#  ('francolomboo', 3),
#  ('veronicaprovder', 3),
#  ('max___brown', 3),
#  ('lau.martinezv', 3),
#  ('mattbermudez_', 3),
#  ('hannnahsanchezz', 3),
#  ('gioseahawks12', 3),
#  ('sarahalymorell', 3),
#  ('kiannarenee', 3),
#  ('justin_behren', 3),
#  ('alecarritola', 3),
#  ('giannaxlombardo', 3),
#  ('jpolay_', 3),
#  ('danielllesharp', 3),
#  ('kerstinmartinez', 3),
#  ('_gabenoguera_', 4),
#  ('allisonhelman', 4),
#  ('kristinasencion', 4),
#  ('madswagmeddrick', 4),
#  ('ninimueller', 4),
#  ('fern_camacho', 4),
#  ('juuliedavidson', 4),
#  ('holliswivell_', 4),
#  ('chloe_shields_', 4),
#  ('jguti__', 4),
#  ('gabrielaaharmon', 4),
#  ('christianrgarciaa', 4),
#  ('carlosgallego97', 4),
#  ('aspenchristen', 4),
#  ('rikkipayne', 4),
#  ('brandon.mackenzie', 4),
#  ('rabarthle', 4),
#  ('danaroberts', 4),
#  ('amynerf', 4),
#  ('_jonathan.rod', 4),
#  ('roc.pile808', 4),
#  ('jonathan_sherman11', 4),
#  ('chase_amm', 4),
#  ('justinhoch13', 4),
#  ('eriinnw', 4),
#  ('jacob_ferreira_', 4),
#  ('15tesh', 4),
#  ('aimee2343', 4),
#  ('juliawhitneyy', 4),
#  ('kelsietaylo', 4),
#  ('big_poppa_cody', 4),
#  ('sid_isabel', 4),
#  ('markcandela', 4),
#  ('morganbailin', 4),
#  ('valentinatheprofessional', 4),
#  ('alxmcknzi', 4),
#  ('isabelle_mundth', 4),
#  ('k.elsbrip', 4),
#  ('cheyennedemers', 4),
#  ('megancentrella', 4),
#  ('isaac_albert', 4),
#  ('mattselimos', 4),
#  ('sammrobyn', 4),
#  ('estefy_roro', 4),
#  ('aratm18', 4),
#  ('halle_berliant', 4),
#  ('sydneyrosholt', 4),
#  ('jakenorman10', 4),
#  ('angiealegria', 4),
#  ('brianfox219', 4),
#  ('ben_bouganim', 4),
#  ('k.barragan', 4),
#  ('jenniewellerr', 4),
#  ('z_stephy', 4),
#  ('ciancimino12', 4),
#  ('justin_lamazares', 4),
#  ('alexschein_', 4),
#  ('loffredojoseph', 4),
#  ('emilyy_nollee', 4),
#  ('gatorswhojuul', 4),
#  ('michael_goutnik', 4),
#  ('___danyphantom', 5),
#  ('nicolechambs', 5),
#  ('sarah.e.schaeffer', 5),
#  ('hayleyduren', 5),
#  ('32kash', 5),
#  ('barathtirumala', 5),
#  ('mattchris12', 5),
#  ('megan_ogburn', 5),
#  ('mr_hopejr', 5),
#  ('skylarjungers', 5),
#  ('kirchenheimer', 5),
#  ('cjtorano', 5),
#  ('jc_contorakes97', 5),
#  ('nickedelstein', 5),
#  ('jezkacohen', 5),
#  ('julissarrozco', 5),
#  ('_bradywalters', 5),
#  ('katedaly7', 5),
#  ('torre.harvey', 5),
#  ('ericabrooke.s', 5),
#  ('marthaarasim', 5),
#  ('donjonnyrose', 5),
#  ('cob_rontento', 5),
#  ('ashchase1', 5),
#  ('kaylee_finney', 5),
#  ('jennyrodrii', 5),
#  ('milena_aimi', 5),
#  ('natashadavalos', 5),
#  ('jswerds', 5),
#  ('ravel_sewell', 5),
#  ('natalieevelev', 5),
#  ('mal.morgan', 5),
#  ('luis.cortez36', 5),
#  ('deniserivchin', 5),
#  ('aznawaj', 5),
#  ('kugs_', 5),
#  ('jovanipastrana', 5),
#  ('francomusicoficial', 5),
#  ('ashleyloeza', 5),
#  ('brittanyobrien6', 5),
#  ('exbropi_pandas', 5),
#  ('hannahforristall', 5),
#  ('danny_is_me', 5),
#  ('billycrystal53', 5),
#  ('samwalkker', 5),
#  ('natalia_gonzalez14', 5),
#  ('calamario_', 5),
#  ('jrussoo', 5),
#  ('hylian_babe', 5),
#  ('ashlyn_marie98', 5),
#  ('timothyye715', 5),
#  ('amitswiss', 5),
#  ('havgarcia', 5),
#  ('nam_was_nutz', 5),
#  ('stairs_kaplan', 5),
#  ('asherrich', 5),
#  ('tonesdavila', 5),
#  ('ry_mcrae', 5),
#  ('deanelsdunne', 5),
#  ('alyssa.perez_', 5),
#  ('vmerttt', 6),
#  ('meghanmclane', 6),
#  ('diegobarreto03', 6),
#  ('angiedimichele', 6),
#  ('fani_ghuman', 6),
#  ('no_reim10', 6),
#  ('chasemarieee', 6),
#  ('julia_sigman', 6),
#  ('zoearmiento', 6),
#  ('tanith.murray', 6),
#  ('shhhheldon', 6),
#  ('yudroye', 6),
#  ('de_nataliejean', 6),
#  ('jay_alexis017', 6),
#  ('hayley_hummel', 6),
#  ('maurigonzalez2', 6),
#  ('gabriella__paul', 6),
#  ('laura_diaz_', 6),
#  ('serenisms', 6),
#  ('clairehaydu', 6),
#  ('emilydoofus', 6),
#  ('jenleestep', 6),
#  ('dani_scavino', 6),
#  ('maris_martino', 6),
#  ('jordan_izen', 6),
#  ('jillianhersman', 6),
#  ('katgotchatongue', 6),
#  ('johncarlo_cerna', 6),
#  ('brooke_garrison', 6),
#  ('_jaimetorres98_', 6),
#  ('melis0sa', 6),
#  ('christianmorales5', 6),
#  ('taylorlight', 6),
#  ('inge_mueller', 6),
#  ('samiryewarrior', 6),
#  ('nickzottoli', 6),
#  ('thegreatguytsby', 6),
#  ('caseycureton', 6),
#  ('cosmicbeanlen', 6),
#  ('brittanyfunderburk', 6),
#  ('mjiiiilly', 6),
#  ('juliarosen_', 6),
#  ('mylesisswole', 6),
#  ('jeong_austin', 6),
#  ('rileytheiger', 6),
#  ('dmillzr', 6),
#  ('bruna.23k1', 6),
#  ('grantchiappelli', 6),
#  ('lozanology', 6),
#  ('luisjarajr', 7),
#  ('mgravy3', 7),
#  ('jess_marie240', 7),
#  ('emiliezuck', 7),
#  ('gabschoe', 7),
#  ('_scottperry', 7),
#  ('365bandzz_', 7),
#  ('baileyyhiggins', 7),
#  ('ryanmorgenlander', 7),
#  ('zoexypteras', 7),
#  ('katie_mihm', 7),
#  ('sary__tary', 7),
#  ('nicolef5061', 7),
#  ('jay.zee.6', 7),
#  ('sabrinastantzyk', 7),
#  ('abby.colleen', 7),
#  ('sebaschin1', 7),
#  ('t_gibbs1108', 7),
#  ('rikkinexx', 7),
#  ('sarahhmmitchell', 7),
#  ('julesalex', 7),
#  ('baby.katess', 7),
#  ('adamsinkoe', 7),
#  ('jayceemerollin', 7),
#  ('romerodan1', 7),
#  ('jcjaramilloq9', 7),
#  ('ryleebattista', 7),
#  ('barbyxtorres', 7),
#  ('amandawysota', 7),
#  ('austineisler23', 7),
#  ('_joshbenbasat', 7),
#  ('viictorrr__', 7),
#  ('danibodner', 7),
#  ('mirsky_', 7),
#  ('kelsey.colbert21', 7),
#  ('leahboxerr', 7),
#  ('itsmattyson', 7),
#  ('sophiadonskoi', 7),
#  ('daleschap', 7),
#  ('andresvilla65', 7),
#  ('sydniewinder', 7),
#  ('cristyinax492', 7),
#  ('alee_moore', 7),
#  ('benribotsky', 7),
#  ('kileycaggiano', 7),
#  ('thatmexican0914', 7),
#  ('sarahjoysherr', 7),
#  ('meredithwilwant', 7),
#  ('hunterramsay', 7),
#  ('bryan2712', 8),
#  ('samsreb', 8),
#  ('_noah_chrl', 8),
#  ('jcriffle51', 8),
#  ('jake_londos', 8),
#  ('sagidmanriquez', 8),
#  ('glennloco', 8),
#  ('marinasantos_', 8),
#  ('daniellafragnito', 8),
#  ('clairelipman', 8),
#  ('chris_estradaa', 8),
#  ('jacobolinick', 8),
#  ('kariina_anne', 8),
#  ('laurenacostaa', 8),
#  ('shellyklein_', 8),
#  ('colbertusmaximus', 8),
#  ('hanrosegrass', 8),
#  ('sophievmartinez_', 8),
#  ('jackson_fulton', 8),
#  ('nabiferra', 8),
#  ('zackthomson.19', 8),
#  ('stephaniespraker', 8),
#  ('haileymmyrick', 8),
#  ('plzgivemesomemo', 8),
#  ('nikkicortland', 8),
#  ('orisalmani', 8),
#  ('anna.demonster', 8),
#  ('arod0530', 8),
#  ('caseyshook', 8),
#  ('mayaacohenn', 8),
#  ('diegogomezz155', 8),
#  ('ojrosete', 8),
#  ('chris__cru', 8),
#  ('stephaniebel0', 8),
#  ('connorfreeston', 9),
#  ('mirandaerrin', 9),
#  ('jbarbosa_02', 9),
#  ('carly_sloane', 9),
#  ('amber__clark', 9),
#  ('fepriolli', 9),
#  ('emmm.allen', 9),
#  ('aidanoc15', 9),
#  ('shelbyreamer', 9),
#  ('haleyjoanna7', 9),
#  ('blake_leeds', 9),
#  ('bekahumansky', 9),
#  ('esbenamoz', 9),
#  ('rachael.a.banach', 9),
#  ('brittutset', 9),
#  ('lanarosepiwoni', 9),
#  ('niikkant', 9),
#  ('thehautemessofficial_', 9),
#  ('skylorfleenor', 9),
#  ('megdora', 9),
#  ('jamie_honowitz', 9),
#  ('mspiegs_', 9),
#  ('matt_garciaaa', 9),
#  ('mollylaurenn', 9),
#  ('bernyyy', 9),
#  ('udynasty', 9),
#  ('santitoodope', 9),
#  ('themichaelkatz', 9),
#  ('alemybarreto', 9),
#  ('charliedaffron', 10),
#  ('hazeber', 10),
#  ('kgray98', 10),
#  ('jmillz1221', 10),
#  ('sbroddd', 10),
#  ('jerobrien', 10),
#  ('_valentinarivera', 10),
#  ('jakeedelstein', 10),
#  ('valenveranooo', 10),
#  ('cuttinggallery', 10),
#  ('catholiccoastie', 10),
#  ('ajtlife', 10),
#  ('madikap', 10),
#  ('hannahkest', 10),
#  ('ssydneyyraee', 10),
#  ('sofiaos98', 10),
#  ('xox_briii_xox', 10),
#  ('jerrica.a', 10),
#  ('nic_band24', 10),
#  ('joshkaiser28', 10),
#  ('giannamangino', 10),
#  ('katelyn_smith8', 10),
#  ('michellevaca', 10),
#  ('lisaxzhu', 10),
#  ('juliogcortez', 10),
#  ('killajimenez_', 10),
#  ('teocanarte', 10),
#  ('seaa_ladyy', 10),
#  ('dantewatson2', 10),
#  ('tahliawilsonn', 10),
#  ('vanessagebala', 10),
#  ('feliciamoniquereich', 10),
#  ('mikeysimon_', 10),
#  ('zoe_mishele', 10),
#  ('_megzk', 10),
#  ('seanna.naylon', 10),
#  ('maddog1372', 10),
#  ('rachsmagz', 10),
#  ('chrisarezz', 10),
#  ('katkourgelis', 10),
#  ('viktortoth1', 11),
#  ('bigty_82', 11),
#  ('curlyygirlyy', 11),
#  ('lord.pious', 11),
#  ('claytonrobinsonn', 11),
#  ('mariaberru', 11),
#  ('brandavz', 11),
#  ('sirpollack', 11),
#  ('j__snider', 11),
#  ('cookiesandcrew', 11),
#  ('yorett.negrin', 11),
#  ('bella_wolsten', 11),
#  ('amandalessner', 11),
#  ('caropazz', 11),
#  ('shelbyausstin', 11),
#  ('njonesy1', 11),
#  ('higginscharli', 11),
#  ('kyperrone', 11),
#  ('ariel_rose12', 11),
#  ('landoncohen', 11),
#  ('morgansimo', 11),
#  ('princesscourtneyy', 11),
#  ('emilykaras', 11),
#  ('taytaybutbut', 11),
#  ('nicoledattero', 11),
#  ('brianalucente', 11),
#  ('samgoldsteinn', 11),
#  ('_veronicamariee_', 11),
#  ('nataliaaospinaa', 11),
#  ('kyndalrock', 11),
#  ('emily_srna', 11),
#  ('mattmourin', 12),
#  ('tylerturner03', 12),
#  ('sarahgillman', 12),
#  ('frankiebusacca', 12),
#  ('tatianaashley', 12),
#  ('katiesagel', 12),
#  ('mbochner29', 12),
#  ('jayjohnz', 12),
#  ('nicole_miladin', 12),
#  ('td954', 12),
#  ('kendalfrazier', 12),
#  ('nick_updike', 12),
#  ('akranaut', 12),
#  ('valleymmm', 12),
#  ('dkotaalynn', 12),
#  ('robertoyuleee', 12),
#  ('solayalaa', 12),
#  ('ronialimaa', 12),
#  ('i_love_jacy', 12),
#  ('diriondo', 12),
#  ('_erin_renee_', 12),
#  ('bree_babyyy06', 12),
#  ('remiiconley', 12),
#  ('bailey_nall', 12),
#  ('josheisner2', 12),
#  ('kyletorres_', 12),
#  ('sophiegarcia13', 12),
#  ('la_ravelo', 12),
#  ('_jennifferrrr', 12),
#  ('kaitcastano', 12),
#  ('anthonyfoti', 12),
#  ('abbyhalem', 13),
#  ('ngoldberg', 13),
#  ('sjapplegate', 13),
#  ('brianforyou', 13),
#  ('macktejeda', 13),
#  ('elainecohen', 13),
#  ('joe_acosta1', 13),
#  ('cj_mazzocchi', 13),
#  ('15yleold', 13),
#  ('dylan_pulitano2', 13),
#  ('takeoffmudine', 13),
#  ('tommy_wind', 13),
#  ('jonmiranda', 13),
#  ('maiapav', 13),
#  ('oliviamendesvir', 13),
#  ('averyalvarez', 13),
#  ('sandra_negrin', 13),
#  ('sarah_wilderr', 13),
#  ('sofiaforwood', 13),
#  ('katherinetagg', 13),
#  ('loganshafer_', 13),
#  ('sofivaleriaa', 13),
#  ('jake_legette', 13),
#  ('migonmcdaniel', 13),
#  ('the3rdknight', 13),
#  ('alexsperos', 13),
#  ('hannahrose____', 13),
#  ('_carly_l', 13),
#  ('marcositu07', 13),
#  ('el_leon17', 13),
#  ('daviputtinato', 13),
#  ('connergmcleod', 13),
#  ('danistoller', 14),
#  ('natsass_', 14),
#  ('tulrich_', 14),
#  ('juliasteger', 14),
#  ('patriciapanyiyun', 14),
#  ('buddyhayward', 14),
#  ('jamiecaustin', 14),
#  ('cassieamundson_', 14),
#  ('ko1500', 14),
#  ('rachelross19', 14),
#  ('jarrodfreedman', 14),
#  ('brookengel', 14),
#  ('carlydaniel', 14),
#  ('danialejaldre', 14),
#  ('jasonbrown__21', 14),
#  ('erikarif', 14),
#  ('natequaffer_', 14),
#  ('saralewittes', 14),
#  ('stefcurrypapi', 14),
#  ('peterhstarr', 14),
#  ('santigaravito', 14),
#  ('cindyluuhu', 14),
#  ('soltobolski', 14),
#  ('daylandaniels', 14),
#  ('eddieklem', 14),
#  ('aridelgreco', 14),
#  ('matt_kab', 14),
#  ('connerfaith', 14),
#  ('pierrevilme', 14),
#  ('free2b_felicia', 14),
#  ('amberfritsche', 14),
#  ('averykatz', 14),
#  ('asian_power0829', 15),
#  ('_kellydanielle_', 15),
#  ('isaachetzroni', 15),
#  ('jacobdarr', 15),
#  ('kyle_s_huntley', 15),
#  ('sirgrahamd', 15),
#  ('thelordoftheswamp', 15),
#  ('ryanamoils', 15),
#  ('cole_kingsberg', 15),
#  ('brittanyconroy', 15),
#  ('greyy______', 15),
#  ('kristikelli', 15),
#  ('jakauff', 15),
#  ('logans1016', 15),
#  ('davis__uno', 15),
#  ('emmalabarbera', 15),
#  ('carowineee', 15),
#  ('savannahfourq', 15),
#  ('miamancuso', 15),
#  ('themaxangel', 15),
#  ('t_brods', 15),
#  ('lharnn', 15),
#  ('cloudyahh_', 15),
#  ('jilldiorio', 15),
#  ('jaderivchin', 15),
#  ('_dbrobeans_', 15),
#  ('bweeezy_', 15),
#  ('_maritza._hernandez_', 15),
#  ('brian_32000', 16),
#  ('morgancmullings', 16),
#  ('maxhermann', 16),
#  ('samm_ashh', 16),
#  ('eric_kroener', 16),
#  ('amandalsnavely', 16),
#  ('harrison_swift', 16),
#  ('amberluboff', 16),
#  ('alanamehaber', 16),
#  ('nikkiidee', 16),
#  ('skylar_kasarjian', 16),
#  ('emdinardi', 16),
#  ('kyleoren01', 16),
#  ('alexzzzandria__', 16),
#  ('bella_forero', 16),
#  ('aapothen', 16),
#  ('ashlahey', 16),
#  ('austin_bagley', 16),
#  ('hanbrry', 16),
#  ('kristenprado', 16),
#  ('jordannicoleheller', 16),
#  ('scott.robins', 16),
#  ('lgundian', 17),
#  ('amymizels', 17),
#  ('beritoca', 17),
#  ('sarah_abramss', 17),
#  ('justin_friedman', 17),
#  ('herman_mike', 17),
#  ('ryanpinosky', 17),
#  ('juliathometz', 17),
#  ('james.pierre7', 17),
#  ('frankditz5', 17),
#  ('alyssacamp', 17),
#  ('valziii_', 17),
#  ('skylerbrandfon', 17),
#  ('nathaliejanette', 17),
#  ('just.trizz', 17),
#  ('king_solomonn', 17),
#  ('britt_littt', 17),
#  ('samantha_laurenr', 17),
#  ('katiefletchh', 17),
#  ('sebasenciso_', 17),
#  ('jacobsuss', 17),
#  ('chloe_jones__', 17),
#  ('courtneyxo7', 17),
#  ('maria.ale.rod', 17),
#  ('giannastarkk', 17),
#  ('meganblum', 17),
#  ('leilawitcher', 18),
#  ('carolinespitz', 18),
#  ('kaley_barbara', 18),
#  ('sreading.11', 18),
#  ('nickmontes24', 18),
#  ('jordanhousman', 18),
#  ('dreanass', 18),
#  ('michellekh_', 18),
#  ('fioreally', 18),
#  ('margotfarren', 18),
#  ('aliyanhaisi', 18),
#  ('janeselopez', 18),
#  ('yanesin_', 18),
#  ('livelaughelizabeth', 18),
#  ('i.ball', 18),
#  ('krista_minas', 18),
#  ('t.wilpon', 18),
#  ('albakato', 18),
#  ('jenna.zaleski', 18),
#  ('jeanellybelly', 18),
#  ('v.arofer', 18),
#  ('stephaleeee', 18),
#  ('laurensteinn', 18),
#  ('kendallberry', 18),
#  ('christywassef', 18),
#  ('nickou.m', 18),
#  ('katelyncarswell', 18),
#  ('lindenclark21', 18),
#  ('sashalibson', 19),
#  ('julessscuccaro', 19),
#  ('little_missmissy', 19),
#  ('natdavzz', 19),
#  ('kbfer97', 19),
#  ('alexhleary', 19),
#  ('emilyrkingg', 19),
#  ('jjbrozier', 19),
#  ('trunkkkk', 19),
#  ('dustinshore', 19),
#  ('ayaataeva', 19),
#  ('theoldkanye', 19),
#  ('chadwick_9__dyr', 19),
#  ('madisonmueller25', 19),
#  ('mattbunsis', 19),
#  ('dchwatt', 19),
#  ('camillemartayan', 19),
#  ('marioalvaa_', 19),
#  ('tylerhorn__', 19),
#  ('dill_f25dy', 19),
#  ('shelbysiegel', 19),
#  ('lizamillie', 19),
#  ('jucoozi', 19),
#  ('connorwmartin', 19),
#  ('zarajoykutty', 19),
#  ('tibet._', 19),
#  ('aryberm', 19),
#  ('roxberman', 20),
#  ('mulkamax123', 20),
#  ('carriinee', 20),
#  ('jake_rheingold', 20),
#  ('zoefineberg', 20),
#  ('victoriajkuhn', 20),
#  ('sami_lieberman', 20),
#  ('cassieegee', 20),
#  ('karissa_lawrence', 20),
#  ('cbaach22', 20),
#  ('jannetjmnz', 20),
#  ('missy0414', 20),
#  ('zoiedanyali', 20),
#  ('jake_p87', 20),
#  ('kevin_rollins', 20),
#  ('nicoleartime', 20),
#  ('rochacone', 20),
#  ('hadzab', 20),
#  ('tannerkelly_', 20),
#  ('izzyd__', 20),
#  ('jmm9t3', 20),
#  ('meganssilverman', 20),
#  ('katieblinderman', 20),
#  ('rachelperwien', 20),
#  ('ravynnicole', 21),
#  ('nicolemorris03', 21),
#  ('aliralli', 21),
#  ('jm.serna', 21),
#  ('louieberk', 21),
#  ('mia.v.padovano', 21),
#  ('ericaeppolito', 21),
#  ('maiaashoshana', 21),
#  ('ryan_williams88', 21),
#  ('aynsleyfanz', 21),
#  ('jaclynweber', 21),
#  ('avanoelcruz', 21),
#  ('chatwell6', 21),
#  ('j_heintskill', 21),
#  ('joshsharan31', 21),
#  ('malcolm.tilokee', 21),
#  ('nicoiturrioz7', 21),
#  ('abelescutiaaa', 21),
#  ('mattman09', 21),
#  ('lalaolsson', 21),
#  ('jemeltz', 21),
#  ('alexaager', 21),
#  ('allychristinejohnson', 21),
#  ('ruchimane_', 21),
#  ('mikeplight', 22),
#  ('kwoods1413', 22),
#  ('jennamlyons', 22),
#  ('marissaacalderon', 22),
#  ('sammieschultz1', 22),
#  ('_kendalllauren', 22),
#  ('tpayne_22', 22),
#  ('talgil24', 22),
#  ('jaylynnrivchin', 22),
#  ('_andrewpratt_', 22),
#  ('shaynagrife', 22),
#  ('shea_ro', 22),
#  ('frypan_delsaucio', 22),
#  ('morgan_fine', 22),
#  ('mollybochner', 22),
#  ('kelly_dreiling', 22),
#  ('sam_herzstein', 22),
#  ('remorlinsky', 22),
#  ('claragoldbaum', 22),
#  ('emily_lombardi', 22),
#  ('caroline_caporella', 22),
#  ('alpalromero', 22),
#  ('joe_weisberg', 22),
#  ('cristianrossi42', 22),
#  ('daphne_bricker', 23),
#  ('emilybriano', 23),
#  ('jennarodriquezz', 23),
#  ('alyssademetriou1010', 23),
#  ('katieee_walker', 23),
#  ('r.horland', 23),
#  ('maxgorfinkel', 23),
#  ('ms_colombianita', 23),
#  ('laurenliketheflower', 23),
#  ('nicolechandeck', 23),
#  ('atticusfitch', 23),
#  ('maria_calaf', 23),
#  ('danielle_chelsey', 23),
#  ('dannyram', 23),
#  ('laurengelman', 23),
#  ('sydeierle', 24),
#  ('barbaramartinez00', 24),
#  ('leamayer', 24),
#  ('thomas__veale', 24),
#  ('lexigipp', 24),
#  ('lindsmcknight1', 24),
#  ('_calvin_ryan', 24),
#  ('landonlupo05', 24),
#  ('gottabehaylee', 24),
#  ('a.assor', 24),
#  ('trizzlemon', 24),
#  ('paytonrosee', 24),
#  ('cmorante7', 24),
#  ('dylan_thoo', 24),
#  ('jake_laz', 24),
#  ('alemayr', 24),
#  ('jakebaumel', 24),
#  ('kelly.ann.f', 24),
#  ('natt__attack', 24),
#  ('_nickpacitti', 24),
#  ('cwachtel45', 24),
#  ('sammistaropoli', 24),
#  ('aliruzbacki', 24),
#  ...]

# %%
n_users = 10 # top 10 users

# %%
pairs = all_pairs[-n_users:]

# %%
pairs
# Out:
# [('savinagomez', 118),
#  ('sydneyritzel', 121),
#  ('erindonovan3', 121),
#  ('samskurnick_', 131),
#  ('__gianna_', 135),
#  ('lau.florezz', 135),
#  ('caseyolivaa', 135),
#  ('erika.fassler', 136),
#  ('priscillagarciaaa', 149),
#  ('livistadt', 150)]

# %%
y = map(lambda y: pairs[y][1], range(len(pairs)))

# %%
y

# %%
x = map(lambda y: pairs[y][0], range(len(pairs)))

# %%
x

# %%
fig = plt.figure()

# %%
plt.xkcd()

# %%
plt.xticks(range(len(pairs)), x, rotation='vertical')
# Out:
# ([<matplotlib.axis.XTick at 0x75b49b0>,
#   <matplotlib.axis.XTick at 0x75b45b0>,
#   <matplotlib.axis.XTick at 0x75b4470>,
#   <matplotlib.axis.XTick at 0x75c6a90>,
#   <matplotlib.axis.XTick at 0x75c6db0>,
#   <matplotlib.axis.XTick at 0x75d00f0>,
#   <matplotlib.axis.XTick at 0x75d0430>,
#   <matplotlib.axis.XTick at 0x75d0750>,
#   <matplotlib.axis.XTick at 0x75d0a70>,
#   <matplotlib.axis.XTick at 0x75d0d90>],
#  <a list of 10 Text xticklabel objects>)

# %%
plt.ylim([80, 160])
# Out:
# (80, 160)

# %%
plt.bar(range(len(pairs)), y)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\jd5\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\units.py in get_converter(self, x)
#     154         try:  # Look up in the cache.
# --> 155             return self[type(x)]
#     156         except KeyError:
#
# KeyError: <class 'map'>
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-34-f992d24f7c68> in <module>
# ----> 1 plt.bar(range(len(pairs)), y)
#
# c:\users\jd5\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2438     return gca().bar(
#    2439         x, height, width=width, bottom=bottom, align=align,
# -> 2440         **({"data": data} if data is not None else {}), **kwargs)
#    2441
#    2442
#
# c:\users\jd5\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# c:\users\jd5\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2346
#    2347         if orientation == 'vertical':
# -> 2348             self._process_unit_info(xdata=x, ydata=height, kwargs=kwargs)
#    2349             if log:
#    2350                 self.set_yscale('log', nonposy='clip')
#
# c:\users\jd5\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\axes\_base.py in _process_unit_info(self, xdata, ydata, kwargs)
#    2124
#    2125         kwargs = _process_single_axis(xdata, self.xaxis, 'xunits', kwargs)
# -> 2126         kwargs = _process_single_axis(ydata, self.yaxis, 'yunits', kwargs)
#    2127         return kwargs
#    2128
#
# c:\users\jd5\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\axes\_base.py in _process_single_axis(data, axis, unit_name, kwargs)
#    2106                 # We only need to update if there is nothing set yet.
#    2107                 if not axis.have_units():
# -> 2108                     axis.update_units(data)
#    2109
#    2110             # Check for units in the kwargs, and if present update axis
#
# c:\users\jd5\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\axis.py in update_units(self, data)
#    1485         """
#    1486
# -> 1487         converter = munits.registry.get_converter(data)
#    1488         if converter is None:
#    1489             return False
#
# c:\users\jd5\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\units.py in get_converter(self, x)
#     156         except KeyError:
#     157             try:  # If cache lookup fails, look up based on first element...
# --> 158                 first = cbook.safe_first_element(x)
#     159             except (TypeError, StopIteration):
#     160                 pass
#
# c:\users\jd5\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\cbook\__init__.py in safe_first_element(obj)
#    1660         except TypeError:
#    1661             pass
# -> 1662         raise RuntimeError("matplotlib does not support generators "
#    1663                            "as input")
#    1664     return next(iter(obj))
#
# RuntimeError: matplotlib does not support generators as input

# %%
plt.xticks(range(len(pairs)), x, rotation='vertical')
# Out:
# ([<matplotlib.axis.XTick at 0x76dec90>,
#   <matplotlib.axis.XTick at 0x76def50>,
#   <matplotlib.axis.XTick at 0x76deab0>,
#   <matplotlib.axis.XTick at 0x76ffa10>,
#   <matplotlib.axis.XTick at 0x76ffd30>,
#   <matplotlib.axis.XTick at 0x77060d0>,
#   <matplotlib.axis.XTick at 0x77063b0>,
#   <matplotlib.axis.XTick at 0x77066d0>,
#   <matplotlib.axis.XTick at 0x77069f0>,
#   <matplotlib.axis.XTick at 0x7706d10>],
#  <a list of 0 Text xticklabel objects>)

# %%
plt.ylim([80, 160])
# Out:
# (80, 160)

# %%
plt.bar(range(len(pairs)), y)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\jd5\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\units.py in get_converter(self, x)
#     154         try:  # Look up in the cache.
# --> 155             return self[type(x)]
#     156         except KeyError:
#
# KeyError: <class 'map'>
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-37-f992d24f7c68> in <module>
# ----> 1 plt.bar(range(len(pairs)), y)
#
# c:\users\jd5\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2438     return gca().bar(
#    2439         x, height, width=width, bottom=bottom, align=align,
# -> 2440         **({"data": data} if data is not None else {}), **kwargs)
#    2441
#    2442
#
# c:\users\jd5\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# c:\users\jd5\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2346
#    2347         if orientation == 'vertical':
# -> 2348             self._process_unit_info(xdata=x, ydata=height, kwargs=kwargs)
#    2349             if log:
#    2350                 self.set_yscale('log', nonposy='clip')
#
# c:\users\jd5\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\axes\_base.py in _process_unit_info(self, xdata, ydata, kwargs)
#    2124
#    2125         kwargs = _process_single_axis(xdata, self.xaxis, 'xunits', kwargs)
# -> 2126         kwargs = _process_single_axis(ydata, self.yaxis, 'yunits', kwargs)
#    2127         return kwargs
#    2128
#
# c:\users\jd5\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\axes\_base.py in _process_single_axis(data, axis, unit_name, kwargs)
#    2106                 # We only need to update if there is nothing set yet.
#    2107                 if not axis.have_units():
# -> 2108                     axis.update_units(data)
#    2109
#    2110             # Check for units in the kwargs, and if present update axis
#
# c:\users\jd5\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\axis.py in update_units(self, data)
#    1485         """
#    1486
# -> 1487         converter = munits.registry.get_converter(data)
#    1488         if converter is None:
#    1489             return False
#
# c:\users\jd5\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\units.py in get_converter(self, x)
#     156         except KeyError:
#     157             try:  # If cache lookup fails, look up based on first element...
# --> 158                 first = cbook.safe_first_element(x)
#     159             except (TypeError, StopIteration):
#     160                 pass
#
# c:\users\jd5\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\cbook\__init__.py in safe_first_element(obj)
#    1660         except TypeError:
#    1661             pass
# -> 1662         raise RuntimeError("matplotlib does not support generators "
#    1663                            "as input")
#    1664     return next(iter(obj))
#
# RuntimeError: matplotlib does not support generators as input

# %%
plt.xlabel('USERS')
# Out:
# Text(0.5, 0, 'USERS')

# %%
plt.ylabel('number of liked posts')
# Out:
# Text(0, 0.5, 'number of liked posts')

# %%
plt.ylim([80, 160])
# Out:
# (80, 160)

# %%
plt.xticks(range(len(pairs)), x, rotation='vertical')
# Out:
# ([<matplotlib.axis.XTick at 0x7587170>,
#   <matplotlib.axis.XTick at 0x7578030>,
#   <matplotlib.axis.XTick at 0x7578e50>,
#   <matplotlib.axis.XTick at 0x7598390>,
#   <matplotlib.axis.XTick at 0x75986b0>,
#   <matplotlib.axis.XTick at 0x75989d0>,
#   <matplotlib.axis.XTick at 0x7598d10>,
#   <matplotlib.axis.XTick at 0x77410f0>,
#   <matplotlib.axis.XTick at 0x7741370>,
#   <matplotlib.axis.XTick at 0x7741690>],
#  <a list of 0 Text xticklabel objects>)

# %%
plt.xkcd()

# %%
plt.xticks(range(len(pairs)), x, rotation='vertical')
# Out:
# ([<matplotlib.axis.XTick at 0x7760070>,
#   <matplotlib.axis.XTick at 0x77551f0>,
#   <matplotlib.axis.XTick at 0x7755110>,
#   <matplotlib.axis.XTick at 0x77751d0>,
#   <matplotlib.axis.XTick at 0x77754f0>,
#   <matplotlib.axis.XTick at 0x7775810>,
#   <matplotlib.axis.XTick at 0x7775b50>,
#   <matplotlib.axis.XTick at 0x7775e70>,
#   <matplotlib.axis.XTick at 0x777e110>,
#   <matplotlib.axis.XTick at 0x7775a90>],
#  <a list of 0 Text xticklabel objects>)

# %%
plt
# Out:
# <module 'matplotlib.pyplot' from 'c:\\users\\jd5\\appdata\\local\\programs\\python\\python37-32\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
print(plt)
# Out:
# <module 'matplotlib.pyplot' from 'c:\\users\\jd5\\appdata\\local\\programs\\python\\python37-32\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
y = map(lambda y: pairs[y][1], range(len(pairs)))

# %%
y

# %%
plt.bar(range(len(pairs)), y)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\jd5\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\units.py in get_converter(self, x)
#     154         try:  # Look up in the cache.
# --> 155             return self[type(x)]
#     156         except KeyError:
#
# KeyError: <class 'map'>
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-48-f992d24f7c68> in <module>
# ----> 1 plt.bar(range(len(pairs)), y)
#
# c:\users\jd5\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2438     return gca().bar(
#    2439         x, height, width=width, bottom=bottom, align=align,
# -> 2440         **({"data": data} if data is not None else {}), **kwargs)
#    2441
#    2442
#
# c:\users\jd5\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# c:\users\jd5\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2346
#    2347         if orientation == 'vertical':
# -> 2348             self._process_unit_info(xdata=x, ydata=height, kwargs=kwargs)
#    2349             if log:
#    2350                 self.set_yscale('log', nonposy='clip')
#
# c:\users\jd5\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\axes\_base.py in _process_unit_info(self, xdata, ydata, kwargs)
#    2124
#    2125         kwargs = _process_single_axis(xdata, self.xaxis, 'xunits', kwargs)
# -> 2126         kwargs = _process_single_axis(ydata, self.yaxis, 'yunits', kwargs)
#    2127         return kwargs
#    2128
#
# c:\users\jd5\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\axes\_base.py in _process_single_axis(data, axis, unit_name, kwargs)
#    2106                 # We only need to update if there is nothing set yet.
#    2107                 if not axis.have_units():
# -> 2108                     axis.update_units(data)
#    2109
#    2110             # Check for units in the kwargs, and if present update axis
#
# c:\users\jd5\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\axis.py in update_units(self, data)
#    1485         """
#    1486
# -> 1487         converter = munits.registry.get_converter(data)
#    1488         if converter is None:
#    1489             return False
#
# c:\users\jd5\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\units.py in get_converter(self, x)
#     156         except KeyError:
#     157             try:  # If cache lookup fails, look up based on first element...
# --> 158                 first = cbook.safe_first_element(x)
#     159             except (TypeError, StopIteration):
#     160                 pass
#
# c:\users\jd5\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\cbook\__init__.py in safe_first_element(obj)
#    1660         except TypeError:
#    1661             pass
# -> 1662         raise RuntimeError("matplotlib does not support generators "
#    1663                            "as input")
#    1664     return next(iter(obj))
#
# RuntimeError: matplotlib does not support generators as input

# %%
y = list(map(lambda y: pairs[y][1], range(len(pairs))))

# %%
x = list(map(lambda y: pairs[y][0], range(len(pairs))))

# %%
fig = plt.figure()
plt.xkcd()
plt.xticks(range(len(pairs)), x, rotation='vertical')
plt.ylim([80, 160])
plt.bar(range(len(pairs)), y)
plt.xlabel('USERS')
plt.ylabel('number of liked posts')
plt.show()

# %%
plt.gcf().clear()

# %%
explode = list(map(lambda i: i/max(y)/10., y))

# %%
fig1, ax1 = plt.subplots()

# %%
ax1.pie(y, explode=explode, 
        labels=x, autopct='%1.1f%%',
        shadow=True, startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x14faca50>,
#   <matplotlib.patches.Wedge at 0x14fb4fb0>,
#   <matplotlib.patches.Wedge at 0x14fb4970>,
#   <matplotlib.patches.Wedge at 0x14fbbbf0>,
#   <matplotlib.patches.Wedge at 0x14fbb6b0>,
#   <matplotlib.patches.Wedge at 0x14fbb8b0>,
#   <matplotlib.patches.Wedge at 0x14fd03b0>,
#   <matplotlib.patches.Wedge at 0x14fd08f0>,
#   <matplotlib.patches.Wedge at 0x14fbb3d0>,
#   <matplotlib.patches.Wedge at 0x14fbbf90>],
#  [Text(-0.32405247327753006, 1.1332453863457053, 'savinagomez'),
#   Text(-0.8812495865629729, 0.785730834294014, 'sydneyritzel'),
#   Text(-1.1661524916966655, 0.18455932349094936, 'erindonovan3'),
#   Text(-1.0753315267429373, -0.5034109176777438, 'samskurnick_'),
#   Text(-0.5758449593645478, -1.0413945375190148, '__gianna_'),
#   Text(0.1568344274610688, -1.179619838067739, 'lau.florezz'),
#   Text(0.8279445544212176, -0.8547559972321059, 'caseyolivaa'),
#   Text(1.175137829028077, -0.191672099947512, 'erika.fassler'),
#   Text(1.0461195143839046, 0.5865444621421535, 'priscillagarciaaa'),
#   Text(0.41603799317814244, 1.1255720271187908, 'livistadt')],
#  [Text(-0.1865867747717905, 0.6525134634049365, '8.9%'),
#   Text(-0.5080495922534135, 0.4529820337742452, '9.1%'),
#   Text(-0.6722990931802908, 0.10640037791318988, '9.1%'),
#   Text(-0.6224968018371523, -0.29141867272641986, '9.8%'),
#   Text(-0.33389329576599824, -0.6038338074690084, '10.1%'),
#   Text(0.09093760920011551, -0.6839812506443192, '10.1%'),
#   Text(0.48006869121902523, -0.4956148219244983, '10.1%'),
#   Text(0.6816588974653347, -0.11118269627414468, '10.2%'),
#   Text(0.6099940914890027, 0.3420150865965086, '11.2%'),
#   Text(0.2426888293539164, 0.6565836824859613, '11.3%')])

# %%
ax1.axis('equal')
# Out:
# (-1.1925196927980735,
#  1.2027051210781337,
#  -1.2039359635926636,
#  1.203213556189385)

# %%
plt.show()
